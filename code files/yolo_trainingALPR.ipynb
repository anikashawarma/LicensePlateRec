# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 136.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="GYBMS7YApJye2mDJdCDw")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-11 in yolov8:: 100%|██████████| 20262/20262 [00:02<00:00, 7165.95it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 75.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import shutil, os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolov8n.pt')

results=model.train(
    data=dataset.location+ "/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16,
    workers=2,
    device=0
)

os.makedirs("saved_models", exist_ok=True)
shutil.copy("/runs/detect/train/weights/best.pt",
            "saved_models/license_plate_best.pt")
shutil.copy("/runs/detect/train/weights/last.pt",
            "saved_models/license_plate_last.pt")
print("Weights saved in saved_models/")
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls
# Out:
# License-Plate-Recognition-11  sample_data   yolo11n.pt
# runs			      saved_models  yolov8n.pt

# %%
# !ls saved_models

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls /content
# Out:
# License-Plate-Recognition-11  sample_data   yolo11n.pt
# runs			      saved_models  yolov8n.pt

# %%
import os, shutil

os.makedirs("/content/saved_models", exist_ok=True)

shutil.copy(
    "/content/runs/detect/train2/weights/best.pt",
    "/content/saved_models/license_plate_best.pt"
)

shutil.copy(
    "/content/runs/detect/train2/weights/last.pt",
    "/content/saved_models/license_plate_last.pt"
)

# !ls /content/saved_models
# Out:
# license_plate_best.pt  license_plate_last.pt

# %%
from google.colab import files
files.download("/content/saved_models/license_plate_best.pt")
